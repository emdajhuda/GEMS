# %%
# illustrative example of use GEMS

# %% [markdown]
# ## Making a custom coadd
#
# > Version: 1.0
# >
# > Container Size: Large
#
# > Description: In this notebook, we present an illustrative example of the use of the GEMS package, where we make a custom coadd from the lsst-distribution.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Complementary info
! echo $IMAGE_DESCRIPTION
! eups list -s | grep lsst_distrib
# Out:
# Release r30.0.11 (RSP Build 3040)
# lsst_distrib          gdfb3db0272+232e9e9820 	v30_0_11 current v30_0_11_rc1 o_latest setup

# %%
# Loading modules
import numpy as np
import gems

# %% [markdown]
# # Making a custom-coadd-filter

# %%
# Coordinates
# within x-degrees of RA, Dec
ra_deg, dec_deg = (53.2, -27.8)

# %%
loc_data = ra_deg, dec_deg

psfSigma_cut, psfStd_cut, airmass_cut = 1.8, 0.05, 1.15

filt_cut = {
    'g': {
    'psfSigma_mean': f' <= {2.1}',
    'psfSigma_std': f' <= {psfStd_cut}',
    'airmass': f' <= {airmass_cut}'
    },
    #
    'r': {
    'psfSigma_mean': f' <= {psfSigma_cut}',
    'psfSigma_std': f' <= {psfStd_cut}',
    'airmass': f' <= {airmass_cut}'
    },
    #
    'i': {
    'psfSigma_mean': f' <= {psfSigma_cut}',
    'psfSigma_std': f' <= {psfStd_cut}',
    'airmass': f' <= {airmass_cut}'
    }
}

# Alternatively, if you can apply the same filter to all bands, you can use:
# filt_cut_select = {
#    'psfSigma_mean': f' <= {psfSigma_cut}',
#    'psfSigma_std': f' <= {psfStd_cut}',
#    'airmass': f' <= {airmass_cut}'
#}
# filt_cut = {name: filt_cut_select for name in bands}

bands = list(filt_cut.keys())
selection = {name: ['psfSigma', 'airmass'] for name in bands}

visits_selected_list, df_metrics_list, coadd_results = gems.custom_coadd_filter(
                    loc_data=loc_data,
                    bands=bands,
                    sky_coordinates=True,
                    butler=None,
                    repository="dp1",
                    collections="LSSTComCam/DP1",
                    skymap_name="lsst_cells_v1",
                    type_coadd='deep_coadd',
                    statistics={'std', 'mean'},
                    selection=selection,
                    filt_cut=filt_cut,
                    plot=True,
                    out=False,
                    my_collection_name='custom_coadd',
                    BUTLER_SAVE_PATH='local_coadd')
# Out:
# [Warning] NaNs in psfSigma_std for visit 2024121000425
# [Warning] NaNs in psfSigma_mean for visit 2024121000425
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Processing pipeline subgraph 1 of 1 with 4 task(s).</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Iterating over data ID query results.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Initial bipartite graph has 28 quanta, 162 dataset nodes, and 228 edges.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Generated 11 quanta for task makeDirectWarp.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Generated 11 quanta for task makePsfMatchedWarp.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Generated 3 quanta for task selectDeepCoaddVisits.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Generated 3 quanta for task assembleDeepCoadd.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Transforming graph skeleton into PredictedQuantumGraph components.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.quantum_graph_builder</span> <span style="color: var(--jp-info-color0)">INFO</span>: Graph build complete.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.daf.butler.direct_butler._direct_butler</span> <span style="color: var(--jp-info-color0)">INFO</span>: Importing 42 datasets into Butler(collections=DirectButlerCollections(defaults=()), run=None, datastore=&#x27;file:///home/jhuda/WORK/gems/examples/local_coadd/&#x27;, registry=&#x27;SQLite3@/home/jhuda/WORK/gems/examples/local_coadd/gen3.sqlite3&#x27;)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;} took 32.900 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800268, band: &#x27;g&#x27;, day_obs: 20241108, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800268, band: &#x27;g&#x27;, day_obs: 20241108, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800268, band: &#x27;g&#x27;, day_obs: 20241108, physical_filter: &#x27;g_01&#x27;} took 33.932 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024111500238, band: &#x27;r&#x27;, day_obs: 20241115, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024111500238, band: &#x27;r&#x27;, day_obs: 20241115, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024111500238, band: &#x27;r&#x27;, day_obs: 20241115, physical_filter: &#x27;r_03&#x27;} took 37.196 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120300135, band: &#x27;g&#x27;, day_obs: 20241203, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120300135, band: &#x27;g&#x27;, day_obs: 20241203, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120300135, band: &#x27;g&#x27;, day_obs: 20241203, physical_filter: &#x27;g_01&#x27;} took 38.850 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500055, band: &#x27;r&#x27;, day_obs: 20241205, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500055, band: &#x27;r&#x27;, day_obs: 20241205, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500055, band: &#x27;r&#x27;, day_obs: 20241205, physical_filter: &#x27;r_03&#x27;} took 12.877 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500060, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500060, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500060, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;} took 24.779 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500064, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500064, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500064, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;} took 6.507 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500065, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500065, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500065, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;} took 35.926 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500066, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500066, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500066, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;} took 27.473 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500067, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500067, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500067, band: &#x27;i&#x27;, day_obs: 20241205, physical_filter: &#x27;i_06&#x27;} took 38.590 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500089, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makeDirectWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500089, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makeDirectWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024120500089, band: &#x27;g&#x27;, day_obs: 20241205, physical_filter: &#x27;g_01&#x27;} took 27.618 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makePsfMatchedWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makePsfMatchedWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (27, 27) to (41, 41)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Copied 198270 pixels from CCD 1 to exposure_psf_matched</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (27, 27) to (41, 41)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Copied 8463537 pixels from CCD 2 to exposure_psf_matched</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (27, 27) to (41, 41)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Copied 1619461 pixels from CCD 5 to exposure_psf_matched</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Total number of good pixels = 10281268</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makePsfMatchedWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800245, band: &#x27;i&#x27;, day_obs: 20241108, physical_filter: &#x27;i_06&#x27;} took 34.923 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makePsfMatchedWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800268, band: &#x27;g&#x27;, day_obs: 20241108, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makePsfMatchedWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800268, band: &#x27;g&#x27;, day_obs: 20241108, physical_filter: &#x27;g_01&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (27, 27) to (41, 41)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Copied 988389 pixels from CCD 4 to exposure_psf_matched</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (27, 27) to (41, 41)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Copied 9659196 pixels from CCD 5 to exposure_psf_matched</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (27, 27) to (41, 41)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Copied 12578 pixels from CCD 8 to exposure_psf_matched</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Total number of good pixels = 10660163</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;makePsfMatchedWarp&#x27; on quantum {instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024110800268, band: &#x27;g&#x27;, day_obs: 20241108, physical_filter: &#x27;g_01&#x27;} took 33.758 seconds</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Preparing execution of quantum for label=makePsfMatchedWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024111500238, band: &#x27;r&#x27;, day_obs: 20241115, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Constructing task and executing quantum for label=makePsfMatchedWarp dataId={instrument: &#x27;LSSTComCam&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34, visit: 2024111500238, band: &#x27;r&#x27;, day_obs: 20241115, physical_filter: &#x27;r_03&#x27;}.</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (27, 27) to (41, 41)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Psf-match science exposure to reference</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: done</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp</span> <span style="color: var(--jp-info-color0)">INFO</span>: Copied 3000483 pixels from CCD 0 to exposure_psf_matched</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: compute Psf-matching kernel</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.makePsfMatchedWarp.psfMatch</span> <span style="color: var(--jp-info-color0)">INFO</span>: Adjusted dimensions of reference PSF model from (27, 27) to (41, 41)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ip.diffim.generateAlardLuptonBasisList</span> <span style="color: var(--jp-info-color0)">INFO</span>: PSF sigmas are not available or scaling by fwhm disabled, falling back to config values</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# ...
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9800), maximum=(15199, 9899))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 9900), maximum=(15199, 9999))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10000), maximum=(15199, 10099))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10100), maximum=(15199, 10199))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10200), maximum=(15199, 10299))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10300), maximum=(15199, 10399))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10400), maximum=(15199, 10499))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10500), maximum=(15199, 10599))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10600), maximum=(15199, 10699))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10700), maximum=(15199, 10799))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10800), maximum=(15199, 10899))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 10900), maximum=(15199, 10999))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11000), maximum=(15199, 11099))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11100), maximum=(15199, 11199))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11200), maximum=(15199, 11299))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11300), maximum=(15199, 11399))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11400), maximum=(15199, 11499))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11500), maximum=(15199, 11599))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11600), maximum=(15199, 11699))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11700), maximum=(15199, 11799))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11800), maximum=(15199, 11899))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 11900), maximum=(15199, 11999))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 12000), maximum=(15199, 12099))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel</span> <span style="color: var(--jp-info-color0)">INFO</span>: Stacking subregion (minimum=(11800, 12100), maximum=(15199, 12199))</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.assembleStaticSkyModel.interpImage</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Negative interpolation edge fallback value computed but negativeFallbackAllowed is False: setting fallbackValue to 0.0</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.detectTemplate</span> <span style="color: var(--jp-info-color0)">INFO</span>: Threshold scaling factor for positive detections is: 1.000. For negative detections it is: 1.000</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.detectTemplate</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 141 positive peaks in 129 footprints and 0 negative peaks in 0 footprints to 300 +ve and 300 -ve sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.detectTemplate</span> <span style="color: var(--jp-info-color0)">INFO</span>: Resubtracting the background after object detection (median background value = -0.12)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.scaleWarpVariance</span> <span style="color: var(--jp-info-color0)">INFO</span>: Renormalizing variance by 1.189105</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Threshold scaling factor for positive detections is: 1.000. For negative detections it is: 1.000</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 1 positive peaks in 1 footprints and 10 negative peaks in 3 footprints to 7.5 +ve and 7.5 -ve sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.maskStreaks</span> <span style="color: var(--jp-info-color0)">INFO</span>: The Kernel Hough Transform detected 0 line(s)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.scaleWarpVariance</span> <span style="color: var(--jp-info-color0)">INFO</span>: Renormalizing variance by 1.251692</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Threshold scaling factor for positive detections is: 1.000. For negative detections it is: 1.000</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.detect</span> <span style="color: var(--jp-info-color0)">INFO</span>: Detected 1 positive peaks in 1 footprints and 0 negative peaks in 0 footprints to 7.5 +ve and 7.5 -ve sigma</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd.maskStreaks</span> <span style="color: var(--jp-info-color0)">INFO</span>: The Kernel Hough Transform detected 0 line(s)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.assembleDeepCoadd</span> <span style="color: var(--jp-info-color0)">INFO</span>: Assembling 2 deepCoadd_directWarp</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.pipe.base.single_quantum_executor</span> <span style="color: var(--jp-info-color0)">INFO</span>: Execution of task &#x27;assembleDeepCoadd&#x27; on quantum {band: &#x27;r&#x27;, skymap: &#x27;lsst_cells_v1&#x27;, tract: 5063, patch: 34} took 30.746 seconds</pre>
